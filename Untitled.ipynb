# %% [markdown]
# $$
# \text{Let } f(x,y) = ln(x+y-1)
# $$

# %%
import numpy as np

def f(x,y):
    return np.log(x+y-1)

print("A) " + str(f(1,1)))
print("B) " + str(f(np.e,1)))
# Out:
# A) 0.0
# B) 1.0

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Make data.
X = np.arange(-2, 20, 0.25)
Y = np.arange(-2, 20, 0.25)
X, Y = np.meshgrid(X, Y)
Z = np.log(X+Y-1)
# Plot the surface.
surf = ax.plot_surface(X, Y, Z, linewidth=0, antialiased=False)
# Customize the z axis.
ax.set_zlim(0, 5)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')
plt.show()
# Out:
# <ipython-input-14-275df8038a65>:12: RuntimeWarning: divide by zero encountered in log
#   Z = np.log(X+Y-1)
# <ipython-input-14-275df8038a65>:12: RuntimeWarning: invalid value encountered in log
#   Z = np.log(X+Y-1)
# <ipython-input-14-275df8038a65>:14: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   surf = ax.plot_surface(X, Y, Z, linewidth=0, antialiased=False)
